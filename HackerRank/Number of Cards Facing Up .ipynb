# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

inputs = [1,1]

exp_face_down = 52

for x in inputs:
    draw_face_up = x*(exp_face_down/52)
    draw_face_down = x - draw_face_up
    exp_face_down = exp_face_down - draw_face_up + draw_face_down
    exp_face_up = 52 - exp_face_down
    
print(f'{exp_face_up:.2f}')
# Out:
# 1.96
